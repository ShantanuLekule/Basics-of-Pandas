# %%
import pandas as pd

# %%
# Read Data
am = pd.read_csv('amazon_reviews.csv')

# %%
am.head()
# Out:
#        Id   ProductId          UserId                ProfileName  \
# 0   59033  B002HQLY7S   AR89H8T4PVWSL                  rumbull01
# 1  514838  B007IVEP8C  A15VHPHU0V8GOH  Judith A. Weller "jw1917"
# 2  419751  B0029ZAOW8  A3CG7K9OQ5M0RI                   reviewer
# 3     870  B000VKYKTG  A1C1Y0S6QPBM4W                  R. Dzuris
# 4  282582  B001EO5WZ4  A2MERSI1KHYIQB     Kathy D. FERRELL "Kat"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                   NaN                     0.0    5.0  1320192000
# 1                   0.0                     0.0    1.0  1345766400
# 2                   2.0                     2.0    5.0  1278633600
# 3                   0.0                     0.0    5.0  1231286400
# 4                   0.0                     0.0    1.0  1325894400
#
#               Summary                                               Text
# 0      Awesome coffee  Purchasing this coffee was definatly worth it!...
# ...

# %%
am.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
# Series
# Every column in data frame is series
type(am['Id'])
# Out:
# pandas.core.series.Series

# %%
# Data Frame
# am is data frame. to extract data frame we use double square brackets
am[['ProductId','UserId']]
# Out:
#       ProductId          UserId
# 0    B002HQLY7S   AR89H8T4PVWSL
# 1    B007IVEP8C  A15VHPHU0V8GOH
# 2    B0029ZAOW8  A3CG7K9OQ5M0RI
# 3    B000VKYKTG  A1C1Y0S6QPBM4W
# 4    B001EO5WZ4  A2MERSI1KHYIQB
# ..          ...             ...
# 995  B0007A0AQW  A2NJSEH07UD6M8
# 996  B0019H0YZ4   ARRVAYRLATRE5
# 997  B003VXL0V6  A2TIGI9VK33WPQ
# 998  B0046HCH5Y  A127NYPMASKWFS
# 999  B001EQ4ZTG  A2A2BPPJTYV4TU
#
# [1000 rows x 2 columns]

# %%
# Basic attributes: shape
am.shape
# Out:
# (1000, 10)

# %%
# columns
am.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
# dtypes
am.dtypes
# Out:
# Id                          int64
# ProductId                  object
# UserId                     object
# ProfileName                object
# HelpfulnessNumerator      float64
# HelpfulnessDenominator    float64
# Score                     float64
# Time                        int64
# Summary                    object
# Text                       object
# dtype: object

# %%
# values
am['ProductId'].values
# Out:
# array(['B002HQLY7S', 'B007IVEP8C', 'B0029ZAOW8', 'B000VKYKTG',
#        'B001EO5WZ4', 'B0042GXR8A', 'B001SIXXWU', 'B001UUOP8C',
#        'B001SB0HNA', 'B00IUY', 'B000HDK0DC', 'B003V5HEXC', 'B000F4094I',
#        'BOOIHJ', 'B001E5E1LE', 'B001EO5KSS', 'B000ER6YO0', 'B000G6MBWI',
#        'B008JKU2CO', 'B00139E43Q', 'B000GFYRJE', 'B001BDDT8K',
#        'B000CQC05K', 'B000B8ZA60', 'B004U49QU2', 'B00271OPVU',
#        'B000UBD88A', 'B001ASCZS6', 'B005C3DTIK', 'B000V17MLS',
#        'B002Z08RIA', 'B0009ETA6W', 'B000VK8AVK', 'B0029O10P4',
#        'B0002HAB64', 'B004RBT8KG', 'B0049Z5OSK', 'B002QWP89S',
#        'B000M36L9E', 'B000ILILLQ', 'B0085YB426', 'B000N5Z5YI',
#        'B000FFIL92', 'B000BRWX0C', 'B000H227BG', 'B004ZY34NC',
#        'B003DKT8AC', 'B002QWP8H0', 'B000KV7ZGQ', 'B0050X8EK0',
#        'B001F653HS', 'B000KV7ZGQ', 'B006E8OGNY', 'B007PA32L2',
#        'B001NJI7GQ', 'B000NP30V8', 'B0014APFB4', 'B0001FQVMK',
#        'B000EHXWIQ', 'B000E4ALGK', 'B002ACQHC6', 'B003120Y4Q',
# ...

# %%
# Basic Functions of pandas
# head
am.head()
# Out:
#        Id   ProductId          UserId                ProfileName  \
# 0   59033  B002HQLY7S   AR89H8T4PVWSL                  rumbull01
# 1  514838  B007IVEP8C  A15VHPHU0V8GOH  Judith A. Weller "jw1917"
# 2  419751  B0029ZAOW8  A3CG7K9OQ5M0RI                   reviewer
# 3     870  B000VKYKTG  A1C1Y0S6QPBM4W                  R. Dzuris
# 4  282582  B001EO5WZ4  A2MERSI1KHYIQB     Kathy D. FERRELL "Kat"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                   NaN                     0.0    5.0  1320192000
# 1                   0.0                     0.0    1.0  1345766400
# 2                   2.0                     2.0    5.0  1278633600
# 3                   0.0                     0.0    5.0  1231286400
# 4                   0.0                     0.0    1.0  1325894400
#
#               Summary                                               Text
# 0      Awesome coffee  Purchasing this coffee was definatly worth it!...
# ...

# %%
# Value Count
am['ProfileName'].value_counts()
# Out:
# Amazon Addict                   2
# Yarii                           2
# Holly K "Book addict"           2
# Zack Davisson                   2
# J. Taylor                       2
#                                ..
# Steven H. Dymond "sdymondpc"    1
# GLH                             1
# blancaJim                       1
# Julia                           1
# J. Bayless                      1
# Name: ProfileName, Length: 985, dtype: int64

# %%
# Describe
am.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count    1000.000000            999.000000              999.000000
# mean   287877.115000              1.852853                2.429429
# std    164630.847881              5.897366                7.275482
# min       518.000000              0.000000                0.000000
# 25%    147610.250000              0.000000                0.000000
# 50%    289888.000000              0.000000                1.000000
# 75%    430994.500000              2.000000                2.000000
# max    568044.000000             96.000000              134.000000
#
#             Score          Time
# count  998.000000  1.000000e+03
# mean     4.191383  1.294445e+09
# std      1.325790  4.914081e+07
# min      1.000000  1.068077e+09
# 25%      4.000000  1.267294e+09
# 50%      5.000000  1.307362e+09
# 75%      5.000000  1.332763e+09
# max      5.000000  1.351210e+09

# %%
# Missing Values
# isnull
am.isnull().sum()
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      1
# HelpfulnessDenominator    1
# Score                     2
# Time                      0
# Summary                   0
# Text                      0
# dtype: int64

# %%
# deletion
am.dropna(subset=['HelpfulnessNumerator'])
# Out:
#          Id   ProductId          UserId                      ProfileName  \
# 1    514838  B007IVEP8C  A15VHPHU0V8GOH        Judith A. Weller "jw1917"
# 2    419751  B0029ZAOW8  A3CG7K9OQ5M0RI                         reviewer
# 3       870  B000VKYKTG  A1C1Y0S6QPBM4W                        R. Dzuris
# 4    282582  B001EO5WZ4  A2MERSI1KHYIQB           Kathy D. FERRELL "Kat"
# 5    551806  B0042GXR8A   AR89H8T4PVWSL                            Linda
# ..      ...         ...             ...                              ...
# 995   65930  B0007A0AQW  A2NJSEH07UD6M8                           Payton
# 996  465157  B0019H0YZ4   ARRVAYRLATRE5                               JK
# 997  393049  B003VXL0V6  A2TIGI9VK33WPQ                    hazeleyesjudi
# 998   79165  B0046HCH5Y  A127NYPMASKWFS  Axis "Freelance Media Designer"
# 999  430883  B001EQ4ZTG  A2A2BPPJTYV4TU                       J. Bayless
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
am.dropna()
# Out:
#          Id   ProductId          UserId                      ProfileName  \
# 1    514838  B007IVEP8C  A15VHPHU0V8GOH        Judith A. Weller "jw1917"
# 2    419751  B0029ZAOW8  A3CG7K9OQ5M0RI                         reviewer
# 3       870  B000VKYKTG  A1C1Y0S6QPBM4W                        R. Dzuris
# 4    282582  B001EO5WZ4  A2MERSI1KHYIQB           Kathy D. FERRELL "Kat"
# 5    551806  B0042GXR8A   AR89H8T4PVWSL                            Linda
# ..      ...         ...             ...                              ...
# 995   65930  B0007A0AQW  A2NJSEH07UD6M8                           Payton
# 996  465157  B0019H0YZ4   ARRVAYRLATRE5                               JK
# 997  393049  B003VXL0V6  A2TIGI9VK33WPQ                    hazeleyesjudi
# 998   79165  B0046HCH5Y  A127NYPMASKWFS  Axis "Freelance Media Designer"
# 999  430883  B001EQ4ZTG  A2A2BPPJTYV4TU                       J. Bayless
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
# Imputation
am['Score'].fillna(0)  # if we want to update data set with fill value shpuld include inplace = True
# Out:
# 0      5.0
# 1      1.0
# 2      5.0
# 3      5.0
# 4      1.0
#       ...
# 995    5.0
# 996    5.0
# 997    5.0
# 998    5.0
# 999    5.0
# Name: Score, Length: 1000, dtype: float64

# %%
df = am.copy()

# %%
df.fillna(0,inplace = True)

# %%
#type casting
am.dtypes
# Out:
# Id                          int64
# ProductId                  object
# UserId                     object
# ProfileName                object
# HelpfulnessNumerator      float64
# HelpfulnessDenominator    float64
# Score                     float64
# Time                        int64
# Summary                    object
# Text                       object
# dtype: object

# %%
df['Score'].unique()
# Out:
# array([5., 1., 2., 4., 0., 3.])

# %%
df['Score'].astype(int)
# Out:
# 0      5
# 1      1
# 2      5
# 3      5
# 4      1
#       ..
# 995    5
# 996    5
# 997    5
# 998    5
# 999    5
# Name: Score, Length: 1000, dtype: int32

# %%
#Adding and Deleting Data
# Add Feature
df['Score_updated'] = df['Score'].astype(int)

# %%
df.head()
# Out:
#        Id   ProductId          UserId                ProfileName  \
# 0   59033  B002HQLY7S   AR89H8T4PVWSL                  rumbull01
# 1  514838  B007IVEP8C  A15VHPHU0V8GOH  Judith A. Weller "jw1917"
# 2  419751  B0029ZAOW8  A3CG7K9OQ5M0RI                   reviewer
# 3     870  B000VKYKTG  A1C1Y0S6QPBM4W                  R. Dzuris
# 4  282582  B001EO5WZ4  A2MERSI1KHYIQB     Kathy D. FERRELL "Kat"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                   0.0                     0.0    5.0  1320192000
# 1                   0.0                     0.0    1.0  1345766400
# 2                   2.0                     2.0    5.0  1278633600
# 3                   0.0                     0.0    5.0  1231286400
# 4                   0.0                     0.0    1.0  1325894400
#
#               Summary                                               Text  \
# 0      Awesome coffee  Purchasing this coffee was definatly worth it!...
# ...

# %%
# Delete Feature
df.drop('Score',axis = 1,inplace = True)

# %%
# Filtering Data
df['Score_updated'] == 5
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Score_updated, Length: 1000, dtype: bool

# %%
filter1 = df['Score_updated'] == 5

# %%
df[filter1]
# Out:
#          Id   ProductId          UserId                      ProfileName  \
# 0     59033  B002HQLY7S   AR89H8T4PVWSL                        rumbull01
# 2    419751  B0029ZAOW8  A3CG7K9OQ5M0RI                         reviewer
# 3       870  B000VKYKTG  A1C1Y0S6QPBM4W                        R. Dzuris
# 7    211680  B001UUOP8C  A15GK1KULYHI12            BG in Chicago "Kiril"
# 8    463996  B001SB0HNA  A1KPALLWZ73M27                       BeagleGrin
# ..      ...         ...             ...                              ...
# 995   65930  B0007A0AQW  A2NJSEH07UD6M8                           Payton
# 996  465157  B0019H0YZ4   ARRVAYRLATRE5                               JK
# 997  393049  B003VXL0V6  A2TIGI9VK33WPQ                    hazeleyesjudi
# 998   79165  B0046HCH5Y  A127NYPMASKWFS  Axis "Freelance Media Designer"
# 999  430883  B001EQ4ZTG  A2A2BPPJTYV4TU                       J. Bayless
#
#      HelpfulnessNumerator  HelpfulnessDenominator        Time  \
# ...

# %%
df[df['Score_updated'] == 5]
# Out:
#          Id   ProductId          UserId                      ProfileName  \
# 0     59033  B002HQLY7S   AR89H8T4PVWSL                        rumbull01
# 2    419751  B0029ZAOW8  A3CG7K9OQ5M0RI                         reviewer
# 3       870  B000VKYKTG  A1C1Y0S6QPBM4W                        R. Dzuris
# 7    211680  B001UUOP8C  A15GK1KULYHI12            BG in Chicago "Kiril"
# 8    463996  B001SB0HNA  A1KPALLWZ73M27                       BeagleGrin
# ..      ...         ...             ...                              ...
# 995   65930  B0007A0AQW  A2NJSEH07UD6M8                           Payton
# 996  465157  B0019H0YZ4   ARRVAYRLATRE5                               JK
# 997  393049  B003VXL0V6  A2TIGI9VK33WPQ                    hazeleyesjudi
# 998   79165  B0046HCH5Y  A127NYPMASKWFS  Axis "Freelance Media Designer"
# 999  430883  B001EQ4ZTG  A2A2BPPJTYV4TU                       J. Bayless
#
#      HelpfulnessNumerator  HelpfulnessDenominator        Time  \
# ...

# %%
# Sorting od Dataframe
df.sort_values(by = 'Score_updated',ascending = False)
# Out:
#          Id   ProductId          UserId                   ProfileName  \
# 0     59033  B002HQLY7S   AR89H8T4PVWSL                     rumbull01
# 597  137192  B001P05K7M  A16RND64P64QKA               Cheryl Schwartz
# 599  516944  B000G1PAC6   AZ4T9C2CQ56G5                       Matthew
# 600  497165  B004E4EBMG  A2ADO5ATT47T5A          S. Urwin "red runts"
# 604   52246  B001EO5YXO  A15H8H0ZE3D28D                Patricia Davis
# ..      ...         ...             ...                           ...
# 750   68916  B004KNJSF6  A2D2QEAMTFVUR3                        katiev
# 921  210310  B001TM70V0  A2DNL3L6YFHH3V           An engineer "Yoshi"
# 845  450042  B000FADLX8  A25BMC59UPBGMD                J. Christensen
# 16      936  B000ER6YO0  A13EBBWOMC0FUI  Sherean Malekzadeh "Sherean"
# 17   217041  B000G6MBWI  A1DMR4TXV10JBB   A. Chrzanowski "Dwarf Mama"
#
#      HelpfulnessNumerator  HelpfulnessDenominator        Time  \
# 0                     0.0                     0.0  1320192000
# ...

# %%
# Apply User Define function
def count_length(feedback):
    return len(feedback)

# %%
df['Text'].apply(count_length)
# Out:
# 0       198
# 1       215
# 2       305
# 3       228
# 4       246
#        ...
# 995     345
# 996    1062
# 997     238
# 998     504
# 999     109
# Name: Text, Length: 1000, dtype: int64

# %%
df['Text'].apply(lambda x: len(x))
# Out:
# 0       198
# 1       215
# 2       305
# 3       228
# 4       246
#        ...
# 995     345
# 996    1062
# 997     238
# 998     504
# 999     109
# Name: Text, Length: 1000, dtype: int64

# %%
# Groupby Function
df.groupby(['UserId'])['Score_updated'].min()
# Out:
# UserId
# #oc-RXFX0AFFBDSJN    5
# A100WO06OQR8BQ       5
# A104M4DKQ96IT0       1
# A1088P38KHFI9B       5
# A10G8ZYR2RVVAE       1
#                     ..
# AZDYF8AXM2GYG        5
# AZLNNFQ88C9E7        1
# AZPOFLFAWXON         5
# AZQZ45Q9U1GNS        5
# AZR55JSEMWB76        4
# Name: Score_updated, Length: 991, dtype: int32

# %%
type(df.groupby(['UserId'])['Score_updated'].min())
# Out:
# pandas.core.series.Series

# %%
df.groupby(['UserId'])['Score_updated'].min().reset_index()
# Out:
#                 UserId  Score_updated
# 0    #oc-RXFX0AFFBDSJN              5
# 1       A100WO06OQR8BQ              5
# 2       A104M4DKQ96IT0              1
# 3       A1088P38KHFI9B              5
# 4       A10G8ZYR2RVVAE              1
# ..                 ...            ...
# 986      AZDYF8AXM2GYG              5
# 987      AZLNNFQ88C9E7              1
# 988       AZPOFLFAWXON              5
# 989      AZQZ45Q9U1GNS              5
# 990      AZR55JSEMWB76              4
#
# [991 rows x 2 columns]

# %%
# Basic Plots
# Bar plot
df['Score_updated'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %%
# Pie Chart
df['Score_updated'].value_counts().plot(kind = 'pie')
# Out:
# <AxesSubplot: ylabel='Score_updated'>

# %%
# Line plot
df['Score_updated'].value_counts().plot()
# Out:
# <AxesSubplot: >
